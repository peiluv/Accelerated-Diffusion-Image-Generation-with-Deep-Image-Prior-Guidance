# %%
class Evaluator:
    def __init__(self, args):
    def evaluate_sample_quality(self, model, num_fid_samples, image_size, channels, tag='default', batch_size=4, real_images=None, **sample_kwargs):
        """
        分批生成樣本，避免 OOM，並計算品質指標（FID、LPIPS、SSIM等）
        model: 具備 .sample 方法的 DDPM / DDIM 模型
        num_fid_samples: 總共要生成多少張圖
        image_size, channels: 生成圖像的尺寸與通道
        batch_size: 每次生成的 batch 數
        real_images: (optional) 真實圖像，用於計算 FID/LPIPS/SSIM
        sample_kwargs: 傳遞給 model.sample 的其他參數
        """
   
    def visualize_samples(self, samples, tag='samples', nrow=None, save=True):
        """
        Visualize and optionally save generated samples.
        """
    

    def compare_samples(self, model_outputs: dict, tag='comparison', save=True):
        """
        Compare samples from different models and visualize them side by side.
        """
     
    def compare_models(self, baseline_ddpm, integrated_model, test_loader, args, dip_prior=None, n_repeats=10):
        """
        Compare baseline DDPM and integrated model by generating samples,
        evaluating quality, and measuring inference time.
        """
